# %% [markdown]
# <a href="https://colab.research.google.com/github/vrao1/Agentic-AI/blob/phase_1/chat_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI
from google.colab import userdata
import os

# %%
key = userdata.get("OPENAI_API_KEY")

# %%
client = OpenAI(api_key=key)

completion = client.chat.completions.create(
    model='gpt-4o',
    messages=[
        {
            'role': 'user',
            'content': 'Write a motivational message for a set of learners learning about AI development'
        }
    ]
)

print(completion.choices[0].message.content)
# Out:
# Absolutely! Here's a motivational message tailored for learners diving into the world of AI development:
#
# ---
#
# Hello Future Innovators,
#
# As you embark on this exciting journey into the realm of AI development, remember that you are stepping into a field that holds the power to transform the world. Whether you’re crafting algorithms that can make decisions, building models that understand complex patterns, or developing systems that learn and evolve, you are at the frontier of innovation.
#
# There will be challenges and puzzles that feel insurmountable at times, but each obstacle is a stepping stone to greater understanding and triumph. Every line of code you write is a building block towards a more intelligent future.
#
# Stay curious, because curiosity fuels innovation. Embrace failures as they are simply lessons in disguise. Collaborate and share your knowledge, for it is in the exchange of ideas that we find the brightest solutions.
#
# ...
