# %% [markdown]
# <a href="https://colab.research.google.com/github/vrao1/Agentic-AI/blob/phase_1/image_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openai import OpenAI
from google.colab import userdata

key = userdata.get('OPENAI_API_KEY')
client = OpenAI(api_key=key)

# %%
response = client.images.generate(
    model="dall-e-3",
    prompt="a futuristic city skyline at sunset, with flying cars and neon lights",
    n=1,
    size='1024x1024',
    quality='standard'
)

# %%
print(response.data[0].url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-WUrCBQ4OwyJYdIRzORmkaD37/user-8c9e6jTGgfoiJaayLtSFBHMf/img-wbXdWGfO3aL65MPaDsOKpO5o.png?st=2026-02-10T20%3A25%3A44Z&se=2026-02-10T22%3A25%3A44Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=67205dde-9780-4119-bbff-6343b48e42b6&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-02-10T07%3A30%3A20Z&ske=2026-02-11T07%3A30%3A20Z&sks=b&skv=2026-02-06&sig=5oRvcwyFua5794P6/F9tLzlVp26Gkq9V1sGnwjIKvyw%3D

# %%
url = response.data[0].url

# %%
print(url)
# Out:
# https://oaidalleapiprodscus.blob.core.windows.net/private/org-WUrCBQ4OwyJYdIRzORmkaD37/user-8c9e6jTGgfoiJaayLtSFBHMf/img-TlfFMlDoORtuEGc6GACeBg8U.png?st=2026-02-10T20%3A35%3A58Z&se=2026-02-10T22%3A35%3A58Z&sp=r&sv=2026-02-06&sr=b&rscd=inline&rsct=image/png&skoid=7aed557a-269d-4dda-ab8b-c66e34024151&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-02-10T12%3A37%3A13Z&ske=2026-02-11T12%3A37%3A13Z&sks=b&skv=2026-02-06&sig=Vj9coIA/2p9nhCW1jirfnghdxtjgzDwudqhFsKDevP0%3D
